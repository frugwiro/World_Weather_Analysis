# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
pip install config
# Out:
# Requirement already satisfied: config in /Users/fiston/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samarai
# Processing Record 2 of Set 1 | skjaerhollen
# City not found. Skipping...
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | freetown
# Processing Record 9 of Set 1 | kalmunai
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | kieta
# Processing Record 15 of Set 1 | sibolga
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | narva-joesuu
# Processing Record 18 of Set 1 | kefalos
# Processing Record 19 of Set 1 | sawtell
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | deputatskiy
# Processing Record 26 of Set 1 | kamogawa
# Processing Record 27 of Set 1 | college
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | vardo
# Processing Record 35 of Set 1 | tura
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | quatre cocos
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | sakakah
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | kozachi laheri
# Processing Record 46 of Set 1 | herat
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | ginsheim-gustavsburg
# Processing Record 49 of Set 1 | pathalgaon
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | korla
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | vanimo
# Processing Record 5 of Set 2 | tiarei
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | flin flon
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | chicama
# Processing Record 11 of Set 2 | lasa
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | gweta
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | vallenar
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | ridgecrest
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | laguna de perlas
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | la paz
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | ewa beach
# Processing Record 30 of Set 2 | vostok
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | bagrami
# Processing Record 37 of Set 2 | rio grande city
# Processing Record 38 of Set 2 | ahuimanu
# Processing Record 39 of Set 2 | dawlatabad
# Processing Record 40 of Set 2 | kargasok
# Processing Record 41 of Set 2 | ushuaia
# Processing Record 42 of Set 2 | la ronge
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | carutapera
# Processing Record 45 of Set 2 | seoul
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | kabinda
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | sepuka
# Processing Record 2 of Set 3 | namatanai
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | luanda
# Processing Record 7 of Set 3 | waingapu
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | dunedin
# Processing Record 11 of Set 3 | abu samrah
# Processing Record 12 of Set 3 | garowe
# Processing Record 13 of Set 3 | marzuq
# Processing Record 14 of Set 3 | lufilufi
# Processing Record 15 of Set 3 | nouadhibou
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | chitipa
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 3 | havelock
# Processing Record 22 of Set 3 | malkangiri
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | vila
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | maceio
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | disna
# Processing Record 30 of Set 3 | ptichye
# Processing Record 31 of Set 3 | toora-khem
# Processing Record 32 of Set 3 | sarandi
# Processing Record 33 of Set 3 | sarh
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | narok
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | bardiyah
# Processing Record 40 of Set 3 | khalandritsa
# City not found. Skipping...
# Processing Record 41 of Set 3 | awbari
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | itaporanga
# Processing Record 44 of Set 3 | mount gambier
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | keningau
# Processing Record 47 of Set 3 | seryshevo
# Processing Record 48 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | chumikan
# Processing Record 1 of Set 4 | christchurch
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | dong hoi
# Processing Record 5 of Set 4 | biggar
# Processing Record 6 of Set 4 | tadine
# Processing Record 7 of Set 4 | kargat
# Processing Record 8 of Set 4 | olafsvik
# Processing Record 9 of Set 4 | komsomolskiy
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | fort nelson
# Processing Record 12 of Set 4 | merauke
# Processing Record 13 of Set 4 | miri
# Processing Record 14 of Set 4 | shenjiamen
# Processing Record 15 of Set 4 | escanaba
# Processing Record 16 of Set 4 | alpena
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | aquin
# Processing Record 19 of Set 4 | zelenoborskiy
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | yar-sale
# Processing Record 22 of Set 4 | kirensk
# Processing Record 23 of Set 4 | coihaique
# Processing Record 24 of Set 4 | zarubino
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | ketchenery
# City not found. Skipping...
# Processing Record 28 of Set 4 | ruteng
# Processing Record 29 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 4 | soto la marina
# Processing Record 31 of Set 4 | jamestown
# Processing Record 32 of Set 4 | swan hill
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | barrow
# Processing Record 35 of Set 4 | calafell
# Processing Record 36 of Set 4 | rancharia
# Processing Record 37 of Set 4 | maldonado
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | asau
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | yellowknife
# Processing Record 43 of Set 4 | maniitsoq
# Processing Record 44 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | ugoofaaru
# Processing Record 47 of Set 4 | charters towers
# Processing Record 48 of Set 4 | moussoro
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | shitanjing
# Processing Record 1 of Set 5 | songkhla
# Processing Record 2 of Set 5 | rio gallegos
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | sumenep
# Processing Record 5 of Set 5 | margate
# Processing Record 6 of Set 5 | snezhnogorsk
# Processing Record 7 of Set 5 | tabory
# Processing Record 8 of Set 5 | tambacounda
# Processing Record 9 of Set 5 | vao
# Processing Record 10 of Set 5 | san rafael
# Processing Record 11 of Set 5 | troitskoye
# Processing Record 12 of Set 5 | pelotas
# Processing Record 13 of Set 5 | ambon
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | kasongo-lunda
# Processing Record 16 of Set 5 | lishui
# Processing Record 17 of Set 5 | ballina
# Processing Record 18 of Set 5 | mossendjo
# Processing Record 19 of Set 5 | bibiani
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | richards bay
# Processing Record 22 of Set 5 | deming
# Processing Record 23 of Set 5 | isabela
# Processing Record 24 of Set 5 | ust-kulom
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | along
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | san benito
# Processing Record 29 of Set 5 | jacareacanga
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | port augusta
# Processing Record 32 of Set 5 | comodoro rivadavia
# Processing Record 33 of Set 5 | suhindol
# Processing Record 34 of Set 5 | istok
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | pasni
# Processing Record 38 of Set 5 | thilogne
# City not found. Skipping...
# Processing Record 39 of Set 5 | saint-michel-des-saints
# Processing Record 40 of Set 5 | labytnangi
# Processing Record 41 of Set 5 | kismayo
# Processing Record 42 of Set 5 | mandvi
# Processing Record 43 of Set 5 | auki
# Processing Record 44 of Set 5 | bintulu
# Processing Record 45 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 46 of Set 5 | oum hadjer
# Processing Record 47 of Set 5 | revelstoke
# Processing Record 48 of Set 5 | hambantota
# Processing Record 49 of Set 5 | usinsk
# Processing Record 50 of Set 5 | clyde river
# Processing Record 1 of Set 6 | riyadh
# Processing Record 2 of Set 6 | ikom
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | puerto quijarro
# Processing Record 6 of Set 6 | najran
# Processing Record 7 of Set 6 | acari
# Processing Record 8 of Set 6 | umm lajj
# Processing Record 9 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 6 | cuxhaven
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | atambua
# Processing Record 13 of Set 6 | ust-tarka
# Processing Record 14 of Set 6 | san carlos
# Processing Record 15 of Set 6 | culfa
# Processing Record 16 of Set 6 | tilichiki
# Processing Record 17 of Set 6 | nyurba
# Processing Record 18 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | dongsheng
# Processing Record 21 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | wanning
# Processing Record 23 of Set 6 | el alto
# Processing Record 24 of Set 6 | venado tuerto
# Processing Record 25 of Set 6 | chor
# Processing Record 26 of Set 6 | iqaluit
# Processing Record 27 of Set 6 | leshan
# Processing Record 28 of Set 6 | barcelos
# Processing Record 29 of Set 6 | tigil
# Processing Record 30 of Set 6 | ahipara
# Processing Record 31 of Set 6 | sovetskaya gavan
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | promyshlennaya
# Processing Record 34 of Set 6 | east london
# Processing Record 35 of Set 6 | oil city
# Processing Record 36 of Set 6 | masindi
# Processing Record 37 of Set 6 | sivaki
# Processing Record 38 of Set 6 | lundazi
# Processing Record 39 of Set 6 | tabou
# Processing Record 40 of Set 6 | haines junction
# Processing Record 41 of Set 6 | fengxian
# Processing Record 42 of Set 6 | goroka
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | woodstock
# Processing Record 45 of Set 6 | puerto baquerizo moreno
# Processing Record 46 of Set 6 | vrangel
# Processing Record 47 of Set 6 | kaitangata
# Processing Record 48 of Set 6 | bambanglipuro
# Processing Record 49 of Set 6 | gualaquiza
# Processing Record 50 of Set 6 | lagoa
# Processing Record 1 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | penzance
# Processing Record 3 of Set 7 | port keats
# Processing Record 4 of Set 7 | bumba
# Processing Record 5 of Set 7 | zhigansk
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | certeze
# Processing Record 8 of Set 7 | marsh harbour
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 7 | puerto del rosario
# Processing Record 12 of Set 7 | floro
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | pokhara
# Processing Record 16 of Set 7 | maraba
# Processing Record 17 of Set 7 | boa esperanca do sul
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | skjervoy
# Processing Record 20 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 7 | kamenka
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | kashi
# Processing Record 24 of Set 7 | crotone
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | nuuk
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 7 | uyuni
# Processing Record 30 of Set 7 | kavarna
# Processing Record 31 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | broken hill
# Processing Record 34 of Set 7 | rio grande
# Processing Record 35 of Set 7 | maymyo
# Processing Record 36 of Set 7 | mayor pablo lagerenza
# Processing Record 37 of Set 7 | ambilobe
# Processing Record 38 of Set 7 | wattegama
# Processing Record 39 of Set 7 | byron bay
# Processing Record 40 of Set 7 | ushtobe
# Processing Record 41 of Set 7 | piney green
# Processing Record 42 of Set 7 | pangnirtung
# Processing Record 43 of Set 7 | andros town
# Processing Record 44 of Set 7 | annemasse
# Processing Record 45 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 7 | mar del plata
# Processing Record 47 of Set 7 | killybegs
# Processing Record 48 of Set 7 | rock sound
# Processing Record 49 of Set 7 | srednekolymsk
# Processing Record 50 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 8 | mogok
# Processing Record 2 of Set 8 | pringsewu
# Processing Record 3 of Set 8 | uyovu
# Processing Record 4 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | aquiraz
# Processing Record 7 of Set 8 | mersing
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | chengmai
# City not found. Skipping...
# Processing Record 10 of Set 8 | saint-pierre
# Processing Record 11 of Set 8 | san quintin
# Processing Record 12 of Set 8 | itamaraca
# Processing Record 13 of Set 8 | dalvik
# Processing Record 14 of Set 8 | beisfjord
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | kaduna
# Processing Record 17 of Set 8 | maiduguri
# Processing Record 18 of Set 8 | kayankulam
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | kirakira
# Processing Record 22 of Set 8 | rafai
# Processing Record 23 of Set 8 | sakura
# Processing Record 24 of Set 8 | plattsburgh
# Processing Record 25 of Set 8 | manzhouli
# Processing Record 26 of Set 8 | qaqortoq
# Processing Record 27 of Set 8 | port moresby
# Processing Record 28 of Set 8 | pangoa
# Processing Record 29 of Set 8 | haimen
# Processing Record 30 of Set 8 | ustyuzhna
# Processing Record 31 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 8 | dunmore east
# Processing Record 33 of Set 8 | kavieng
# Processing Record 34 of Set 8 | progreso
# Processing Record 35 of Set 8 | lubao
# Processing Record 36 of Set 8 | malanje
# Processing Record 37 of Set 8 | mwinilunga
# Processing Record 38 of Set 8 | oia
# Processing Record 39 of Set 8 | iida
# Processing Record 40 of Set 8 | lesnoye
# Processing Record 41 of Set 8 | kodiak
# Processing Record 42 of Set 8 | sosnovka
# Processing Record 43 of Set 8 | cedar city
# Processing Record 44 of Set 8 | diamantino
# Processing Record 45 of Set 8 | nizhniy kuranakh
# Processing Record 46 of Set 8 | fereydun kenar
# Processing Record 47 of Set 8 | wahiawa
# Processing Record 48 of Set 8 | douglas
# Processing Record 49 of Set 8 | sola
# Processing Record 50 of Set 8 | solnechnyy
# Processing Record 1 of Set 9 | juneau
# Processing Record 2 of Set 9 | trairi
# Processing Record 3 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 4 of Set 9 | requena
# Processing Record 5 of Set 9 | bako
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | poronaysk
# Processing Record 9 of Set 9 | kazaki
# Processing Record 10 of Set 9 | brandon
# Processing Record 11 of Set 9 | orange cove
# Processing Record 12 of Set 9 | acapulco
# Processing Record 13 of Set 9 | matara
# Processing Record 14 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 9 | dandong
# Processing Record 16 of Set 9 | mocuba
# Processing Record 17 of Set 9 | kruisfontein
# Processing Record 18 of Set 9 | rongcheng
# Processing Record 19 of Set 9 | bac lieu
# Processing Record 20 of Set 9 | golovino
# Processing Record 21 of Set 9 | northam
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | skibbereen
# Processing Record 24 of Set 9 | sulangan
# Processing Record 25 of Set 9 | podor
# Processing Record 26 of Set 9 | rockland
# Processing Record 27 of Set 9 | arona
# Processing Record 28 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 9 | coihueco
# Processing Record 30 of Set 9 | puerto leguizamo
# Processing Record 31 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 9 | severo-kurilsk
# Processing Record 33 of Set 9 | pimentel
# Processing Record 34 of Set 9 | wajima
# Processing Record 35 of Set 9 | akhisar
# Processing Record 36 of Set 9 | loreto
# Processing Record 37 of Set 9 | khovu-aksy
# Processing Record 38 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 9 | tuatapere
# Processing Record 40 of Set 9 | wagar
# Processing Record 41 of Set 9 | marsabit
# Processing Record 42 of Set 9 | ternate
# Processing Record 43 of Set 9 | marivan
# Processing Record 44 of Set 9 | tessalit
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | diego de almagro
# Processing Record 47 of Set 9 | kununurra
# Processing Record 48 of Set 9 | vaitape
# Processing Record 49 of Set 9 | birao
# Processing Record 50 of Set 9 | grootfontein
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | chimbote
# Processing Record 3 of Set 10 | sayyan
# Processing Record 4 of Set 10 | abha
# Processing Record 5 of Set 10 | labuhan
# Processing Record 6 of Set 10 | puro
# Processing Record 7 of Set 10 | jibuti
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | evensk
# Processing Record 10 of Set 10 | dwarka
# Processing Record 11 of Set 10 | banting
# Processing Record 12 of Set 10 | ashland
# Processing Record 13 of Set 10 | aborlan
# Processing Record 14 of Set 10 | wanaka
# Processing Record 15 of Set 10 | naze
# Processing Record 16 of Set 10 | marmaron
# City not found. Skipping...
# Processing Record 17 of Set 10 | wuwei
# Processing Record 18 of Set 10 | makakilo city
# Processing Record 19 of Set 10 | wewak
# Processing Record 20 of Set 10 | vestmannaeyjar
# Processing Record 21 of Set 10 | dossor
# Processing Record 22 of Set 10 | kazachinskoye
# Processing Record 23 of Set 10 | russell
# Processing Record 24 of Set 10 | okhotsk
# Processing Record 25 of Set 10 | nyagan
# Processing Record 26 of Set 10 | coahuayana
# Processing Record 27 of Set 10 | hearst
# Processing Record 28 of Set 10 | bakchar
# Processing Record 29 of Set 10 | yambio
# Processing Record 30 of Set 10 | gondar
# Processing Record 31 of Set 10 | sitka
# Processing Record 32 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 10 | longview
# Processing Record 34 of Set 10 | mushie
# Processing Record 35 of Set 10 | roald
# Processing Record 36 of Set 10 | lincoln
# Processing Record 37 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 10 | acarau
# Processing Record 39 of Set 10 | algiers
# Processing Record 40 of Set 10 | deniliquin
# Processing Record 41 of Set 10 | corinto
# Processing Record 42 of Set 10 | seymchan
# Processing Record 43 of Set 10 | impfondo
# Processing Record 44 of Set 10 | edd
# Processing Record 45 of Set 10 | nea karvali
# Processing Record 46 of Set 10 | tuy hoa
# Processing Record 47 of Set 10 | emerald
# Processing Record 48 of Set 10 | erzin
# Processing Record 49 of Set 10 | syedove
# Processing Record 50 of Set 10 | bauru
# Processing Record 1 of Set 11 | amapa
# Processing Record 2 of Set 11 | narimanov
# Processing Record 3 of Set 11 | johnstown
# Processing Record 4 of Set 11 | luwuk
# Processing Record 5 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 11 | bratsk
# Processing Record 7 of Set 11 | hualmay
# Processing Record 8 of Set 11 | igarka
# Processing Record 9 of Set 11 | valpoi
# Processing Record 10 of Set 11 | nelson bay
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | egvekinot
# Processing Record 13 of Set 11 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 14 of Set 11 | mollendo
# Processing Record 15 of Set 11 | wilkie
# Processing Record 16 of Set 11 | katobu
# Processing Record 17 of Set 11 | inhambane
# Processing Record 18 of Set 11 | palmer
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | vawkavysk
# Processing Record 21 of Set 11 | bilma
# Processing Record 22 of Set 11 | zharkent
# Processing Record 23 of Set 11 | rumonge
# Processing Record 24 of Set 11 | tecpan
# Processing Record 25 of Set 11 | powell
# Processing Record 26 of Set 11 | touros
# Processing Record 27 of Set 11 | lubango
# Processing Record 28 of Set 11 | codrington
# Processing Record 29 of Set 11 | gizo
# Processing Record 30 of Set 11 | winnemucca
# Processing Record 31 of Set 11 | buraydah
# Processing Record 32 of Set 11 | muli
# Processing Record 33 of Set 11 | mugango
# Processing Record 34 of Set 11 | dogondoutchi
# Processing Record 35 of Set 11 | cabra
# Processing Record 36 of Set 11 | lahat
# Processing Record 37 of Set 11 | viedma
# Processing Record 38 of Set 11 | nakonde
# Processing Record 39 of Set 11 | raga
# Processing Record 40 of Set 11 | perelyub
# Processing Record 41 of Set 11 | lucapa
# Processing Record 42 of Set 11 | avera
# Processing Record 43 of Set 11 | north bend
# Processing Record 44 of Set 11 | portland
# Processing Record 45 of Set 11 | kuzhener
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | taltal
# Processing Record 48 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 11 | miandrivazo
# Processing Record 50 of Set 11 | broome
# Processing Record 1 of Set 12 | murgab
# Processing Record 2 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | san cristobal
# Processing Record 5 of Set 12 | vohibinany
# Processing Record 6 of Set 12 | grindavik
# Processing Record 7 of Set 12 | athabasca
# Processing Record 8 of Set 12 | matagami
# Processing Record 9 of Set 12 | umba
# Processing Record 10 of Set 12 | abatskoye
# Processing Record 11 of Set 12 | dickinson
# Processing Record 12 of Set 12 | ossora
# Processing Record 13 of Set 12 | aklavik
# Processing Record 14 of Set 12 | arica
# Processing Record 15 of Set 12 | patnos
# Processing Record 16 of Set 12 | tiznit
# Processing Record 17 of Set 12 | ladysmith
# Processing Record 18 of Set 12 | turayf
# Processing Record 19 of Set 12 | vilcun
# Processing Record 20 of Set 12 | dieppe
# Processing Record 21 of Set 12 | point pleasant
# Processing Record 22 of Set 12 | balkhash
# Processing Record 23 of Set 12 | kaura namoda
# Processing Record 24 of Set 12 | verkhnyaya inta
# Processing Record 25 of Set 12 | kochi
# Processing Record 26 of Set 12 | kapoeta
# Processing Record 27 of Set 12 | yakymivka
# Processing Record 28 of Set 12 | sisimiut
# Processing Record 29 of Set 12 | hofn
# Processing Record 30 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 12 | phan thiet
# Processing Record 32 of Set 12 | crepy-en-valois
# Processing Record 33 of Set 12 | porto novo
# Processing Record 34 of Set 12 | craig
# Processing Record 35 of Set 12 | lalibela
# Processing Record 36 of Set 12 | bara
# Processing Record 37 of Set 12 | bam
# Processing Record 38 of Set 12 | careiro da varzea
# Processing Record 39 of Set 12 | coos bay
# Processing Record 40 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 12 | huejuquilla el alto
# Processing Record 42 of Set 12 | lukiv
# Processing Record 43 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | port hawkesbury
# Processing Record 45 of Set 12 | ust-tsilma
# Processing Record 46 of Set 12 | nome
# Processing Record 47 of Set 12 | nador
# Processing Record 48 of Set 12 | salinas
# Processing Record 49 of Set 12 | tezu
# Processing Record 50 of Set 12 | nabire
# Processing Record 1 of Set 13 | tiksi
# Processing Record 2 of Set 13 | tommot
# Processing Record 3 of Set 13 | cheremukhovo
# Processing Record 4 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 13 | cacador
# Processing Record 6 of Set 13 | marevo
# Processing Record 7 of Set 13 | ketchikan
# Processing Record 8 of Set 13 | lazaro cardenas
# Processing Record 9 of Set 13 | ambatofinandrahana
# Processing Record 10 of Set 13 | santa cruz del sur
# Processing Record 11 of Set 13 | saint-joseph
# Processing Record 12 of Set 13 | boende
# Processing Record 13 of Set 13 | altay
# Processing Record 14 of Set 13 | las cruces
# Processing Record 15 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | yabrud
# Processing Record 17 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 13 | upernavik
# Processing Record 19 of Set 13 | fort morgan
# Processing Record 20 of Set 13 | apad
# Processing Record 21 of Set 13 | pontian kecil
# Processing Record 22 of Set 13 | salym
# Processing Record 23 of Set 13 | carnot
# Processing Record 24 of Set 13 | caconda
# Processing Record 25 of Set 13 | maarianhamina
# Processing Record 26 of Set 13 | poum
# Processing Record 27 of Set 13 | tefe
# Processing Record 28 of Set 13 | navalmoral de la mata
# Processing Record 29 of Set 13 | decines-charpieu
# Processing Record 30 of Set 13 | kalemie
# Processing Record 31 of Set 13 | lichinga
# Processing Record 32 of Set 13 | lensk
# Processing Record 33 of Set 13 | koslan
# Processing Record 34 of Set 13 | angoche
# Processing Record 35 of Set 13 | dudinka
# Processing Record 36 of Set 13 | sovetskiy
# Processing Record 37 of Set 13 | calvinia
# Processing Record 38 of Set 13 | lavrentiya
# Processing Record 39 of Set 13 | karasjok
# Processing Record 40 of Set 13 | mehamn
# Processing Record 41 of Set 13 | thinadhoo
# Processing Record 42 of Set 13 | bandundu
# Processing Record 43 of Set 13 | karratha
# Processing Record 44 of Set 13 | tancheng
# Processing Record 45 of Set 13 | cabanas
# Processing Record 46 of Set 13 | anqing
# Processing Record 47 of Set 13 | port hardy
# Processing Record 48 of Set 13 | gribanovskiy
# Processing Record 49 of Set 13 | beyneu
# Processing Record 50 of Set 13 | prieska
# Processing Record 1 of Set 14 | fukue
# Processing Record 2 of Set 14 | bereda
# Processing Record 3 of Set 14 | alamosa
# Processing Record 4 of Set 14 | san andres
# Processing Record 5 of Set 14 | wasilla
# Processing Record 6 of Set 14 | praia
# Processing Record 7 of Set 14 | meadow lake
# Processing Record 8 of Set 14 | normandin
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | capim grosso
# Processing Record 11 of Set 14 | port pirie
# Processing Record 12 of Set 14 | coffs harbour
# Processing Record 13 of Set 14 | novikovo
# Processing Record 14 of Set 14 | aykhal
# Processing Record 15 of Set 14 | sorland
# Processing Record 16 of Set 14 | harkany
# Processing Record 17 of Set 14 | repalle
# Processing Record 18 of Set 14 | whyalla
# Processing Record 19 of Set 14 | klaksvik
# Processing Record 20 of Set 14 | dakar
# Processing Record 21 of Set 14 | hirara
# Processing Record 22 of Set 14 | pag
# Processing Record 23 of Set 14 | carauari
# Processing Record 24 of Set 14 | razgrad
# Processing Record 25 of Set 14 | florianopolis
# Processing Record 26 of Set 14 | booue
# Processing Record 27 of Set 14 | harper
# Processing Record 28 of Set 14 | port hedland
# Processing Record 29 of Set 14 | iquique
# Processing Record 30 of Set 14 | rajpipla
# Processing Record 31 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 32 of Set 14 | jimbolia
# Processing Record 33 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 14 | save
# Processing Record 35 of Set 14 | ust-kut
# Processing Record 36 of Set 14 | ocos
# Processing Record 37 of Set 14 | nizhnyaya omka
# Processing Record 38 of Set 14 | laguna
# Processing Record 39 of Set 14 | mtwara
# Processing Record 40 of Set 14 | san luis
# Processing Record 41 of Set 14 | tazovskiy
# Processing Record 42 of Set 14 | randvere
# City not found. Skipping...
# Processing Record 43 of Set 14 | wakkanai
# Processing Record 44 of Set 14 | jawhar
# Processing Record 45 of Set 14 | uni
# Processing Record 46 of Set 14 | tynda
# Processing Record 47 of Set 14 | black river
# Processing Record 48 of Set 14 | penukonda
# Processing Record 49 of Set 14 | lashio
# Processing Record 50 of Set 14 | mackay
# Processing Record 1 of Set 15 | constantine
# Processing Record 2 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 15 | nhulunbuy
# Processing Record 4 of Set 15 | puerto escondido
# Processing Record 5 of Set 15 | inta
# Processing Record 6 of Set 15 | tual
# Processing Record 7 of Set 15 | adrar
# Processing Record 8 of Set 15 | ambovombe
# Processing Record 9 of Set 15 | nchelenge
# Processing Record 10 of Set 15 | vanavara
# Processing Record 11 of Set 15 | roma
# Processing Record 12 of Set 15 | nanakuli
# Processing Record 13 of Set 15 | arlit
# Processing Record 14 of Set 15 | linxia
# Processing Record 15 of Set 15 | santa isabel
# Processing Record 16 of Set 15 | ntcheu
# Processing Record 17 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 18 of Set 15 | erenhot
# Processing Record 19 of Set 15 | vangaindrano
# Processing Record 20 of Set 15 | austin
# Processing Record 21 of Set 15 | granja
# Processing Record 22 of Set 15 | fallon
# Processing Record 23 of Set 15 | san jose de guanipa
# Processing Record 24 of Set 15 | hobyo
# Processing Record 25 of Set 15 | shingu
# Processing Record 26 of Set 15 | rundu
# Processing Record 27 of Set 15 | baykit
# Processing Record 28 of Set 15 | buchmany
# Processing Record 29 of Set 15 | barabai
# Processing Record 30 of Set 15 | severnyy
# Processing Record 31 of Set 15 | quelimane
# Processing Record 32 of Set 15 | port-gentil
# Processing Record 33 of Set 15 | petrozavodsk
# Processing Record 34 of Set 15 | paamiut
# Processing Record 35 of Set 15 | tsogni
# Processing Record 36 of Set 15 | tambura
# Processing Record 37 of Set 15 | ambo
# Processing Record 38 of Set 15 | finote selam
# Processing Record 39 of Set 15 | saint-ambroise
# Processing Record 40 of Set 15 | voi
# Processing Record 41 of Set 15 | kulynychi
# Processing Record 42 of Set 15 | shakawe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
